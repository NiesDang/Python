# %%
pip install tableone
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from tableone import TableOne

# %matplotlib inline

# %%
listdf2: [df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]

# %%
def readdata(y):
    
    x = pd.read_csv(y,sep='	')
    x= x[[(x['AGE2']> 3)] and (x['AGE2']<=13)]
    x.loc[x['MJEVER'] > 5, 'MJEVER'] = np.nan
    x.loc[x['MJYFU'] > 900, 'MJYFU'] = np.nan
    x.loc[x['HERYFU'] > 900, 'HERYFU'] = np.nan
    x.loc[x['MJMFU'] > 80, 'MJMFU'] = np.nan
    x.loc[x['HERYFU'] > 800, 'HERYFU'] = np.nan
    x.loc[x['HERMFU'] > 80, 'HERMFU'] = np.nan
    x.loc[x['COCEVER'] > 80, 'COCEVER'] = np.nan
    x.loc[x['HEREVER'] > 80, 'HEREVER'] = np.nan
    x.loc[x['METHAMEVR'] > 80, 'METHAMEVR'] = np.nan

    return x

# %%
df10 = readdata('NSDUH_2010_Tab.csv')
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_14544/3479575668.py:1: DtypeWarning: Columns (2575) have mixed types.Specify dtype option on import or set low_memory=False.
#   df19 = readdata('NSDUH_2019_Tab.csv')

# %%
df11 = readdata('NSDUH_2011_Tab.csv')

# %%
df12 = readdata('NSDUH_2012_Tab.csv')

# %%
df13 = readdata('NSDUH_2013_Tab.csv')

# %%
df10 = readdata('NSDUH_2010_Tab.csv')

# %%
df18 = readdata('NSDUH_2018_Tab.csv')
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_24952/2758257887.py:1: DtypeWarning: Columns (2525) have mixed types.Specify dtype option on import or set low_memory=False.
#   df18 = readdata('NSDUH_2018_Tab.csv')

# %%
df19= readdata('NSDUH_2019_Tab.csv')
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_24952/2035134017.py:1: DtypeWarning: Columns (2575) have mixed types.Specify dtype option on import or set low_memory=False.
#   df19= readdata('NSDUH_2019_Tab.csv')

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31530 entries, 3 to 56135
# Columns: 2741 entries, QUESTID2 to VEREP
# dtypes: float64(407), int64(2332), object(2)
# memory usage: 659.6+ MB

# %%
.apply(lambda x : x if x <5   else np.nan)

# %%
df19= df19[[(df19['AGE2']> 3)] and (df19['AGE2']<=13)]
df19
# Out:
#        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# 6      65565143  10/09/2020        2        99        99     991    9991
# 13     79876143  10/09/2020        1        99        99       9    9999
# 15     58786143  10/09/2020        2         4         4     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
#        CIGMFU  CIGREC  CIG30USE  ...  POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# ...

# %%
def dfyouth(x):
    x= x[(x['AGE2'] > 3) & (x['AGE2'] <=13)]
    return x

# %%
dfyouth(df19)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24952/3659310480.py in <module>
# ----> 1 dfyouth(df19)
#
# NameError: name 'dfyouth' is not defined

# %%
df20.apply(dfyouth)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20756/200601379.py in <module>
# ----> 1 df20.apply(dfyouth)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ...

# %%
listdf = [df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]
for i in listdf:
    dfyouth(i)

# %%
dfyouth(df19)
# Out:
#        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# 6      65565143  10/09/2020        2        99        99     991    9991
# 13     79876143  10/09/2020        1        99        99       9    9999
# 15     58786143  10/09/2020        2         4         4     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
#        CIGMFU  CIGREC  CIG30USE  ...  POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# ...

# %%
df19
# Out:
#        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 0      43295143  10/09/2020        1        99        99      13    9999
# 1      65095143  10/09/2020        2        99        99     991    9991
# 2      49405143  10/09/2020        1        99        99      22    9999
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
#        CIGMFU  CIGREC  CIG30USE  ...  POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# ...

# %%
df19.describe
# Out:
# <bound method NDFrame.describe of        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 0      43295143  10/09/2020        1        99        99      13    9999
# 1      65095143  10/09/2020        2        99        99     991    9991
# 2      49405143  10/09/2020        1        99        99      22    9999
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
# ...

# %%
df19[['MJEVER','YESCHFLT']]
# Out:
#        MJEVER  YESCHFLT
# 3           2        99
# 4           2        99
# 6           1        99
# 13          1        99
# 15          2         1
# ...       ...       ...
# 56131       1        99
# 56132       1        99
# 56133       2         2
# 56134       1         3
# 56135       2         2
#
# [31530 rows x 2 columns]

# %%
df19['MJEVER']
# Out:
# 3        2
# 4        2
# 6        1
# 13       1
# 15       2
#         ..
# 56131    1
# 56132    1
# 56133    2
# 56134    1
# 56135    2
# Name: MJEVER, Length: 31530, dtype: int64

# %%
df19['YESCHFLT'].dtypes
# Out:
# dtype('float64')

# %%
df19['YESCHFLT'].astype('str')
# Out:
# 3        nan
# 4        nan
# 6        nan
# 13       nan
# 15       1.0
#         ...
# 56131    nan
# 56132    nan
# 56133    2.0
# 56134    3.0
# 56135    2.0
# Name: YESCHFLT, Length: 31530, dtype: object

# %%
df19['YESCHFLT']= df19['YESCHFLT'].astype('category')

# %%
def dataconverting(x):
    if x <5:
        x == x
    else: 
        x == np.nan
    return x

# %%
df19['YESCHFLT'] = df19['YESCHFLT'].apply(lambda x : x if x <5   else np.nan)

# %%
df19.loc[df19['MJEVER'] > 5, 'MJEVER'] = np.nan
df19.loc[df19['MJYFU'] > 900, 'MJYFU'] = np.nan
df19.loc[df19['HERYFU'] > 900, 'HERYFU'] = np.nan
df19.loc[df19['MJMFU'] > 80, 'MJMFU'] = np.nan
df19.loc[df19['HERYFU'] > 800, 'HERYFU'] = np.nan
df19.loc[df19['HERMFU'] > 80, 'HERMFU'] = np.nan
df19.loc[df19['COCEVER'] > 80, 'COCEVER'] = np.nan

df19.loc[df19['HEREVER'] > 80, 'HEREVER'] = np.nan

df19.loc[df19['METHAMEVR'] > 80, 'METHAMEVR'] = np.nan
df19['YESCHFLT'] = df19['YESCHFLT'].apply(lambda x : x if x <5   else np.nan)

# %%
df19.loc[df19['MJEVER'] > 5, 'MJYFU'] = np.nan

# %%
df19['YESCHFLT'] = df19['YESCHFLT'].apply(lambda x : x if x <5   else np.nan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20756/675123139.py in <module>
# ----> 1 df19['YESCHFLT'] = df19['YESCHFLT'].apply(lambda x : x if x <5   else np.nan)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
df19['YESCHWRK'] = df19['YESCHWRK'].apply(lambda x : x if x <5   else np.nan)

# %%
df19['YESCHWRK'].astype('category')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# 3        NaN
# 4        NaN
# 6        NaN
# 13       NaN
# 15       1.0
#         ...
# 56131    NaN
# 56132    NaN
# 56133    2.0
# 56134    3.0
# 56135    1.0
# Name: YESCHWRK, Length: 31530, dtype: category
# Categories (4, float64): [1.0, 2.0, 3.0, 4.0]

# %%
df19['YESCHIMP'] = df19['YESCHIMP'].apply(lambda x : x if x <5   else np.nan)

# %%
df19['YESCHIMP'].astype('category')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# 3        NaN
# 4        NaN
# 6        NaN
# 13       NaN
# 15       2.0
#         ...
# 56131    NaN
# 56132    NaN
# 56133    2.0
# 56134    3.0
# 56135    2.0
# Name: YESCHIMP, Length: 31530, dtype: category
# Categories (4, float64): [1.0, 2.0, 3.0, 4.0]

# %%
df19['YESCHINT'] = df19['YESCHINT'].apply(lambda x : x if x <5   else np.nan)

# %%
df119 = df19.apply(dfyouth)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20756/1476293887.py in <module>
# ----> 1 df119 = df19.apply(dfyouth)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ...

# %%
df19['YESCHINT'].astype('category')
# Out:
# 3        NaN
# 4        NaN
# 6        NaN
# 13       NaN
# 15       1.0
#         ...
# 56131    NaN
# 56132    NaN
# 56133    2.0
# 56134    2.0
# 56135    2.0
# Name: YESCHINT, Length: 31530, dtype: float64

# %%
df19['YETCGJOB1'] = df19['YETCGJOB1'].apply(lambda x : x if x <5   else np.nan)

# %%
df19['YESCHINT'].astype('category')

# %%
df19['YELSTGRD1'] = df19['YELSTGRD1'].apply(lambda x : x if x <5   else np.nan)

# %%
df19['YELSTGRD1'].astype('category')

# %%
datatest = df19

# %%
df19
# Out:
#        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# 6      65565143  10/09/2020        2        99        99     991    9991
# 13     79876143  10/09/2020        1        99        99       9    9999
# 15     58786143  10/09/2020        2         4         4     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
#        CIGMFU  CIGREC  CIG30USE  ...  POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# ...

# %%
list1 = ['YESCHFLT',
'YESCHWRK',
'YESCHIMP', 
'YESCHINT' ,
'YETCGJOB',
'YELSTGRD',
'YEPCHKHW',
'YEPHLPHW',
'YEPCHORE',
'YEPLMTTV',
'YEPLMTSN',
'YEPPROUD',
'YEYARGUP',
'YEYFGTSW',
'YEYFGTGP', 
'YEYHGUN', 
'YEYSELL',
'YEYSTOLE',
'YEYATTAK',
'YEVIOPRV',
'YESCHACT',
'YECOMACT',
'YEFAIACT',
'YEOTHACT',
'DSTNRV30',
'DSTNRV30',
'DSTCHR30',
'DSTNGD30',
'IMPSOC',
'IMPSOCM',
'YODPREV']
def dataclean(x):
        for y in list1:
                x[y]= x[y].apply(lambda a : a if a <80 else np.nan)

# %%
dataclean(df19)

# %%
df19
# Out:
#        QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  \
# 3      51015143  10/09/2020        2        99        99     991    9991
# 4      31825143  10/09/2020        2        99        99     991    9991
# 6      65565143  10/09/2020        2        99        99     991    9991
# 13     79876143  10/09/2020        1        99        99       9    9999
# 15     58786143  10/09/2020        2         4         4     991    9991
# ...         ...         ...      ...       ...       ...     ...     ...
# 56131  29424730  10/09/2020        1        99        99      17    9999
# 56132  71744730  10/09/2020        2        99        99     991    9991
# 56133  38044730  10/09/2020        2         4         4     991    9991
# 56134  43164730  10/09/2020        2         3         4     991    9991
# 56135  92074730  10/09/2020        2         4         4     991    9991
#
#        CIGMFU  CIGREC  CIG30USE  ...  POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# ...

# %%
df19[['YESCHFLT',
'YESCHWRK',
'YESCHIMP', 
'YESCHINT' ,
'YETCGJOB',
'YELSTGRD',
'YEPCHKHW',
'YEPHLPHW',
'YEPCHORE',
'YEPLMTTV',
'YEPLMTSN',
'YEPPROUD',
'YEYARGUP',
'YEYFGTSW',
'YEYFGTGP', 
'YEYHGUN', 
'YEYSELL',
'YEYSTOLE',
'YEYATTAK',
'YEVIOPRV',
'YESCHACT',
'YECOMACT',
'YEFAIACT',
'YEOTHACT',
'DSTNRV30',
'DSTNRV30',
'DSTCHR30',
'DSTNGD30',
'IMPSOC',
'IMPSOCM',
'YODPREV']]
# Out:
#        YESCHFLT  YESCHWRK  YESCHIMP  YESCHINT  YETCGJOB  YELSTGRD  YEPCHKHW  \
# 3           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 15          1.0       1.0       2.0       1.0       1.0       2.0       1.0
# ...         ...       ...       ...       ...       ...       ...       ...
# 56131       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 56132       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 56133       2.0       2.0       2.0       2.0       1.0       2.0       1.0
# 56134       3.0       3.0       3.0       2.0       1.0       1.0       2.0
# 56135       2.0       1.0       2.0       2.0       1.0       2.0       2.0
#
# ...

# %%
def datatype(x):
    for a in list1:                
                x[a] = x[a].astype('category')

# %%
df19[['YESCHFLT',
'YESCHWRK',
'YESCHIMP', 
'YESCHINT' ,
'YETCGJOB',
'YELSTGRD',
'YEPCHKHW',
'YEPHLPHW',
'YEPCHORE',
'YEPLMTTV',
'YEPLMTSN',
'YEPPROUD',
'YEYARGUP',
'YEYFGTSW',
'YEYFGTGP', 
'YEYHGUN', 
'YEYSELL',
'YEYSTOLE',
'YEYATTAK',
'YEVIOPRV',
'YESCHACT',
'YECOMACT',
'YEFAIACT',
'YEOTHACT',
'DSTNRV30',
'DSTNRV30',
'DSTCHR30',
'DSTNGD30',
'IMPSOC',
'IMPSOCM',
'YODPREV']].apply(lambda x: x.astype('category'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14544/3424766134.py in <module>
# ----> 1 df19[['YESCHFLT',
#       2 'YESCHWRK',
#       3 'YESCHIMP',
#       4 'YESCHINT' ,
#       5 'YETCGJOB',
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#    1004
#    1005         # handle the dup indexing case GH#4246
# -> 1006         return self.loc[key]
#    1007
#    1008     def _get_values_tuple(self, key):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
# ...

# %%
df19[['YESCHFLT','YESCHWRK','YESCHIMP', 'YESCHINT' ,'YETCGJOB','YELSTGRD','YEPCHKHW','YEPHLPHW','YEPCHORE','YEPLMTTV','YEPLMTSN','YEPPROUD','YEYARGUP','YEYFGTSW','YEYFGTGP', 'YEYHGUN', 'YEYSELL','YEYSTOLE','YEYATTAK','YEVIOPRV',
'YESCHACT','YECOMACT','YEFAIACT','YEOTHACT','DSTNRV30','DSTNRV30','DSTCHR30','DSTNGD30','IMPSOC','IMPSOCM','YODPREV']].dtypes
# Out:
# YESCHFLT    float64
# YESCHWRK    float64
# YESCHIMP    float64
# YESCHINT    float64
# YETCGJOB    float64
# YELSTGRD    float64
# YEPCHKHW    float64
# YEPHLPHW    float64
# YEPCHORE    float64
# YEPLMTTV    float64
# YEPLMTSN    float64
# YEPPROUD    float64
# YEYARGUP    float64
# YEYFGTSW    float64
# YEYFGTGP    float64
# YEYHGUN     float64
# YEYSELL     float64
# YEYSTOLE    float64
# YEYATTAK    float64
# YEVIOPRV    float64
# YESCHACT    float64
# YECOMACT    float64
# YEFAIACT    float64
# YEOTHACT    float64
# DSTNRV30    float64
# DSTNRV30    float64
# DSTCHR30    float64
# DSTNGD30    float64
# IMPSOC      float64
# IMPSOCM     float64
# YODPREV     float64
# dtype: object

# %%
df19.astype('category')
# Out:
#        QUESTID2    FILEDATE CIGEVER CIGOFRSM CIGWILYR CIGTRY CIGYFU CIGMFU  \
# 3      51015143  10/09/2020       2       99       99    991   9991     91
# 4      31825143  10/09/2020       2       99       99    991   9991     91
# 6      65565143  10/09/2020       2       99       99    991   9991     91
# 13     79876143  10/09/2020       1       99       99      9   9999     99
# 15     58786143  10/09/2020       2        4        4    991   9991     91
# ...         ...         ...     ...      ...      ...    ...    ...    ...
# 56131  29424730  10/09/2020       1       99       99     17   9999     99
# 56132  71744730  10/09/2020       2       99       99    991   9991     91
# 56133  38044730  10/09/2020       2        4        4    991   9991     91
# 56134  43164730  10/09/2020       2        3        4    991   9991     91
# 56135  92074730  10/09/2020       2        4        4    991   9991     91
#
# ...

# %%
df19.dtypes
# Out:
# QUESTID2      int64
# FILEDATE     object
# CIGEVER       int64
# CIGOFRSM      int64
# CIGWILYR      int64
#              ...
# MAIIN102      int64
# AIIND102      int64
# ANALWT_C    float64
# VESTR         int64
# VEREP         int64
# Length: 2741, dtype: object

# %%
dataclean(df19)

# %%
datatype(df19)

# %%
df19['YESCHFLT'] = df19['YESCHFLT'].astype('str')

# %%
columns = ['MJEVER','COCEVER','METHAMFLAG','HEREVER','METHAMEVR','YESCHFLT','YESCHWRK','YESCHIMP', 'YESCHINT' ,'YETCGJOB','YELSTGRD','YEPCHKHW','YEPHLPHW','YEPCHORE','YEPLMTTV','YEPLMTSN','YEPPROUD','YEYARGUP','YEYFGTSW','YEYFGTGP', 'YEYHGUN', 'YEYSELL','YEYSTOLE','YEYATTAK','YEVIOPRV',
'YESCHACT','YECOMACT','YEFAIACT','YEOTHACT','DSTNRV30','DSTCHR30','DSTNGD30','IMPSOC','IMPSOCM','YODPREV']
categorical = ['MJEVER','COCEVER','METHAMFLAG','HEREVER','METHAMEVR','YESCHFLT','YESCHWRK','YESCHIMP', 'YESCHINT' ,'YETCGJOB','YELSTGRD','YEPCHKHW','YEPHLPHW','YEPCHORE','YEPLMTTV','YEPLMTSN','YEPPROUD','YEYARGUP','YEYFGTSW','YEYFGTGP', 'YEYHGUN', 'YEYSELL','YEYSTOLE','YEYATTAK','YEVIOPRV',
'YESCHACT','YECOMACT','YEFAIACT','YEOTHACT','DSTNRV30','DSTCHR30','DSTNGD30','IMPSOC','IMPSOCM','YODPREV']
groupby = 'MJEVER'#Total_Drinkday,
nonnormal = []

# %%
mytable19 = TableOne(df19, columns=columns ,categorical = categorical,missing= True, groupby=groupby)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\tableone\tableone.py:991: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df['percent'] = df['freq'].div(df.freq.sum(level=0),

# %%
mytable20 = TableOne(dataclean(dfyouth(df20)), columns=columns ,categorical = categorical,missing= True, groupby=groupby)
# Out:
# C:\Users\tn09t\AppData\Local\Temp/ipykernel_20756/364456033.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[y]= x[y].apply(lambda a : a if a <80 else np.nan)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20756/3611004788.py in <module>
# ----> 1 mytable20 = TableOne(dataclean(dfyouth(df20)), columns=columns ,categorical = categorical,missing= True, groupby=groupby)
#
# ...

# %%
print(mytable19.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════╤═════╤═══════════╤══════════════╤═══════════════╤═══════════════╕
# │                   │     │ Missing   │ Overall      │ 1.0           │ 2.0           │
# ╞═══════════════════╪═════╪═══════════╪══════════════╪═══════════════╪═══════════════╡
# │ n                 │     │           │ 31530        │ 12216         │ 19289         │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │ MJEVER, n (%)     │ 1.0 │ 25        │ 12216 (38.8) │ 12216 (100.0) │               │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │                   │ 2.0 │           │ 19289 (61.2) │               │ 19289 (100.0) │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │ COCEVER, n (%)    │ 1.0 │ 10        │ 2366 (7.5)   │ 2322 (19.0)   │ 44 (0.2)      │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# ...

# %%
dataclean(df18)

# %%
mytable18 = TableOne(df18, columns=columns ,categorical = categorical,missing= True, groupby=groupby)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\tableone\tableone.py:991: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   df['percent'] = df['freq'].div(df.freq.sum(level=0),

# %%
print(mytable18.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════╤═════╤═══════════╤══════════════╤═══════════════╤═══════════════╕
# │                   │     │ Missing   │ Overall      │ 1.0           │ 2.0           │
# ╞═══════════════════╪═════╪═══════════╪══════════════╪═══════════════╪═══════════════╡
# │ n                 │     │           │ 30792        │ 11493         │ 19268         │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │ MJEVER, n (%)     │ 1.0 │ 31        │ 11493 (37.4) │ 11493 (100.0) │               │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │                   │ 2.0 │           │ 19268 (62.6) │               │ 19268 (100.0) │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# │ COCEVER, n (%)    │ 1.0 │ 15        │ 2300 (7.5)   │ 2264 (19.7)   │ 35 (0.2)      │
# ├───────────────────┼─────┼───────────┼──────────────┼───────────────┼───────────────┤
# ...

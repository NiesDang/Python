# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %matplotlib inline

# %%
#load dataset drug
df21 = pd.read_csv('NSDUH_2021_Tab.csv',sep = '	')
df21.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\3146097231.py:2: DtypeWarning: Columns (2792) have mixed types. Specify dtype option on import or set low_memory=False.
#   df21 = pd.read_csv('NSDUH_2021_Tab.csv',sep = '	')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58034 entries, 0 to 58033
# Columns: 2988 entries, QUESTID2 to VEREP
# dtypes: float64(539), int64(2447), object(2)
# memory usage: 1.3+ GB

# %%
def readdata3(y):
    
    x = pd.read_csv(y,sep='	')
    x= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
    return y

# %%
#load dataset drug
df20 = pd.read_csv('NSDUH_2020_Tab.csv',sep = '	')
df20.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\898225204.py:2: DtypeWarning: Columns (2726) have mixed types. Specify dtype option on import or set low_memory=False.
#   df20 = pd.read_csv('NSDUH_2020_Tab.csv',sep = '	')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32893 entries, 0 to 32892
# Columns: 2890 entries, QUESTID2 to VEREP
# dtypes: float64(429), int64(2459), object(2)
# memory usage: 725.3+ MB

# %%
df19 = pd.read_csv('NSDUH_2019_Tab.csv',sep = '	'  )
df19.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\1205317429.py:1: DtypeWarning: Columns (2575) have mixed types. Specify dtype option on import or set low_memory=False.
#   df19 = pd.read_csv('NSDUH_2019_Tab.csv',sep = '	'  )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56136 entries, 0 to 56135
# Columns: 2741 entries, QUESTID2 to VEREP
# dtypes: float64(407), int64(2332), object(2)
# memory usage: 1.1+ GB

# %%
df18 = pd.read_csv('NSDUH_2018_Tab.csv',sep = '	'  )
df18.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\1733563532.py:1: DtypeWarning: Columns (2525) have mixed types. Specify dtype option on import or set low_memory=False.
#   df18 = pd.read_csv('NSDUH_2018_Tab.csv',sep = '	'  )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56313 entries, 0 to 56312
# Columns: 2691 entries, QUESTID2 to VEREP
# dtypes: float64(408), int64(2281), object(2)
# memory usage: 1.1+ GB

# %%
df17 = pd.read_csv('NSDUH_2017_Tab.csv',sep = '	' )
df17.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\2907571387.py:1: DtypeWarning: Columns (2502) have mixed types. Specify dtype option on import or set low_memory=False.
#   df17 = pd.read_csv('NSDUH_2017_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56276 entries, 0 to 56275
# Columns: 2668 entries, QUESTID2 to VEREP
# dtypes: float64(407), int64(2259), object(2)
# memory usage: 1.1+ GB

# %%
df16 = pd.read_csv('NSDUH_2016_Tab.csv',sep = '	' )
df16.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\2161852738.py:1: DtypeWarning: Columns (2506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df16 = pd.read_csv('NSDUH_2016_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56897 entries, 0 to 56896
# Columns: 2668 entries, QUESTID2 to VEREP
# dtypes: float64(409), int64(2257), object(2)
# memory usage: 1.1+ GB

# %%
df15 = pd.read_csv('NSDUH_2015_Tab.csv',sep = '	' )
df15.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\2106065787.py:1: DtypeWarning: Columns (2514) have mixed types. Specify dtype option on import or set low_memory=False.
#   df15 = pd.read_csv('NSDUH_2015_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57146 entries, 0 to 57145
# Columns: 2679 entries, QUESTID2 to VEREP
# dtypes: float64(408), int64(2269), object(2)
# memory usage: 1.1+ GB

# %%
df14 = pd.read_csv('NSDUH_2014_Tab.csv',sep = '	' )
df14.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\59712587.py:1: DtypeWarning: Columns (2946) have mixed types. Specify dtype option on import or set low_memory=False.
#   df14 = pd.read_csv('NSDUH_2014_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55271 entries, 0 to 55270
# Columns: 3034 entries, QUESTID2 to VEREP
# dtypes: float64(519), int64(2513), object(2)
# memory usage: 1.2+ GB

# %%
df13 = pd.read_csv('NSDUH_2013_Tab.csv',sep = '	' )
df13.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\500310104.py:1: DtypeWarning: Columns (2954) have mixed types. Specify dtype option on import or set low_memory=False.
#   df13 = pd.read_csv('NSDUH_2013_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55160 entries, 0 to 55159
# Columns: 3040 entries, QUESTID2 to VEREP
# dtypes: float64(526), int64(2512), object(2)
# memory usage: 1.2+ GB

# %%
df12 = pd.read_csv('NSDUH_2012_Tab.csv',sep = '	' )
df12.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\1702412959.py:1: DtypeWarning: Columns (2975) have mixed types. Specify dtype option on import or set low_memory=False.
#   df12 = pd.read_csv('NSDUH_2012_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55268 entries, 0 to 55267
# Columns: 3054 entries, QUESTID2 to VEREP
# dtypes: float64(561), int64(2491), object(2)
# memory usage: 1.3+ GB

# %%
df11 = pd.read_csv('NSDUH_2011_Tab.csv',sep = '	' )
df11.info()
# Out:
# C:\Users\tn09t\AppData\Local\Temp\ipykernel_14748\1177881976.py:1: DtypeWarning: Columns (2947) have mixed types. Specify dtype option on import or set low_memory=False.
#   df11 = pd.read_csv('NSDUH_2011_Tab.csv',sep = '	' )
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58397 entries, 0 to 58396
# Columns: 3026 entries, QUESTID2 to VEREP
# dtypes: float64(537), int64(2487), object(2)
# memory usage: 1.3+ GB

# %%
df10 = pd.read_csv('NSDUH_2010_Tab.csv',sep = '	' )
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57313 entries, 0 to 57312
# Columns: 3033 entries, QUESTID2 to VEREP
# dtypes: float64(540), int64(2491), object(2)
# memory usage: 1.3+ GB

# %%
#noweedu18
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 noweedu18
#
# NameError: name 'noweedu18' is not defined

# %%
u18weed = []
o18weed = []
noweedu18 = []
noweedo18 =[]
ea = []
def riskratio(x):    
        
        y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
        a= x[[(x['AGE2']>=4)] and (x['AGE2']<=6)]
        m= y[(y['MJEVER']==1)]
        s= y[(y['MJEVER']==0)]
        Q= a[(a['MJEVER']==1)]
        z= a[(a['MJEVER']==0)]
        u18weed.append(m)
        #apply fuction count every single code at 1 time not all of them
        noweedu18.append(len(s))
        o18weed.append(Q)
        noweedo18.append(z)
        ea = len(u18weed)/(len(u18weed)+len(noweedu18))
        ae = len(o18weed)/(len(o18weed)+len(noweedo18))

# %%
len(u18weed)
# Out:
# 0

# %%
riskratio(df10)

# %%
riskratio(df10)

# %%
def cleancanabis(x):
    o18 = []
    u18 = []
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
        m= y[(y['MJEVER']==1)]
        a = (len(m)/len(y))*100
        
    else:
        y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
        m= y[(y['MJEVER']==1)]
        a = (len(m)/len(y))*100

    return a

# %%
cleancanabis(df10)
# Out:
# 5.9340164395901365

# %%
def cleancanabiso18(x):
   
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 3)] and (x['AGE2']<=6)]
        m= y[(y['MJEVER']==1)]
        a = (len(m)/len(y))*100
        
    else:
        y= x[[(x['AGE3']> 3)] and (x['AGE3']<=6)]
        m= y[(y['MJEVER']==1)]
        a = (len(m)/len(y))*100

    return a

# %%
#def cleancanabis(x):
 #   o18 = []
  #  u18 = []
   # for data in x:
   #   DAS  if 'AGE2' in x.columns:
    #        if x[[(x['AGE2']> 1)] and (x['AGE2']<=3)] and m == y[(y['MJEVER']==1)]:
     #          u18.append()
      #      elif x[[(x['AGE2']> 1)] and (x['AGE2']<=3)] and m == y[(y['MJEVER']==1)]:
       #      b = len()        
    #else:
     #   y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
      #  m= y[(y['MJEVER']==1)]
       # a = (len(m)/len(y))*100
# Out:
#   File <tokenize>:10
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#cleancanabis(df10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cleancanabis(df10)
#
# Cell In[29], line 6, in cleancanabis(x)
#       4 for data in x:
#       5     if 'AGE2' in x.columns:
# ----> 6         if x[[(x['AGE2']> 1)] and (x['AGE2']<=3)] and m == y[(y['MJEVER']==1)]:
#       7            u18.append()
#       8         elif x[[(x['AGE2']> 1)] and (x['AGE2']<=3)] and m == y[(y['MJEVER']==1)]:
#
# File c:\Users\tn09t\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ...

# %%
cleanmarijuanaper(df18)
# Out:
# 4.794730392156863

# %%
cleanmarijuanaper21(df21)
# Out:
# 12.342920971795587

# %%
# Make a random dataset:
def plot():
    o18 = []
    u18 = []
    height = [cleancanabis(df10),cleancanabis(df11),cleancanabis(df12),cleancanabis(df13),cleancanabis(df14),
    cleancanabis(df15),cleancanabis(df16),cleancanabis(df17),cleancanabis(df18), cleancanabis(df19),cleancanabis(df20),cleancanabis(df21)]
    bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
    y_pos = np.arange(len(bars))

# Create bars
    plt.bar(y_pos, height)

# Create names on the x-axis
    plt.xticks(y_pos, bars)
    plt.xlabel('Marijuana in Kids under 18 by years', fontweight='bold', fontsize=15)
    plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic
plt.show()

# %%
def cleanmarijuanaper212 (x):
    y= x[[(x['AGE3']> 4)] and (x['AGE3']<=13)]
    m= y[(y['MJEVER']==1)]
    a = (len(m)/len(y))*100
    return a

# %%
height = [cleancanabis(df10),cleancanabis(df11),cleancanabis(df12),cleancanabis(df13),cleancanabis(df14),
cleancanabis(df15),cleancanabis(df16),cleancanabis(df17),cleancanabis(df18), cleancanabis(df19),cleancanabis(df20),cleancanabis(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Marijuana in Kids adult >18 and < 26 ', fontweight='bold', fontsize=15)
plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
fig.subplots_adjust(wspace=0.3)
plt.subplot(1, 2, 2)


# Make a random dataset:
height = [cleancanabiso18(df10),cleancanabiso18(df11),cleancanabiso18(df12),cleancanabiso18(df13),cleancanabiso18(df14),
cleancanabiso18(df15),cleancanabiso18(df16),cleancanabiso18(df17),cleancanabiso18(df18), cleancanabiso18(df19),cleancanabiso18(df20),cleancanabiso18(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Marijuana in adult >18 and < 26 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)




plt.subplot(1, 2, 1)

height = [cleancanabis(df10),cleancanabis(df11),cleancanabis(df12),cleancanabis(df13),cleancanabis(df14),
cleancanabis(df15),cleancanabis(df16),cleancanabis(df17),cleancanabis(df18), cleancanabis(df19),cleancanabis(df20),cleancanabis(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Marijuana in Kids under 18 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic

plt.suptitle("marijuana over year between 2 groups", fontweight='bold', fontsize=30)
plt.show()

# %%
def cleancocain(x):
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
        m= y[(y['COCEVER']==1)]
        a = (len(m)/len(y))*100
        
    else:
        y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
        m= y[(y['COCEVER']==1)]
        a = (len(m)/len(y))*100

    return a

# %%
def cleancocaino18(x):
   
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 3)] and (x['AGE2']<=6)]
        m= y[(y['COCEVER']==1)]
        a = (len(m)/len(y))*100
        
    else:
        y= x[[(x['AGE3']> 3)] and (x['AGE3']<=6)]
        m= y[(y['COCEVER']==1)]
        a = (len(m)/len(y))*100

    return a

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
fig.subplots_adjust(wspace=0.3)
plt.subplot(1, 2, 2)


# Make a random dataset:
height = [cleancocaino18(df10),cleancocaino18(df11),cleancocaino18(df12),cleancocaino18(df13),cleancocaino18(df14),
cleancocaino18(df15),cleancocaino18(df16),cleancocaino18(df17),cleancocaino18(df18), cleancocaino18(df19),cleancocaino18(df20),cleancocaino18(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Cocain in adult >18 and < 26 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)




plt.subplot(1, 2, 1)

height = [cleancocain(df10),cleancocain(df11),cleancocain(df12),cleancocain(df13),cleancocain(df14),
cleancocain(df15),cleancocain(df16),cleancocain(df17),cleancocain(df18), cleancocain(df19),cleancocain(df20),cleancocain(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Cocain in Kids under 18 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic

plt.suptitle("Cocain over year between 2 groups", fontweight='bold', fontsize=30)
plt.show()

# %%
def cleanmeth18(x):

    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 3)] and (x['AGE2']<=6)]
        m= y[(y['METHAMFLAG']==1)]
        a = (len(m)/len(y))/100

    else:
        y= x[[(x['AGE3']> 3)] and (x['AGE3']<=6)]
        m= y[(y['METHAMFLAG']==1)]
        a = (len(m)/len(y))/100

    return a

# %%
def cleanmeth(x):
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
        m= y[(y['METHAMFLAG']==1)]
        a = (len(m)/len(y))/100

    else:
        y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
        m= y[(y['METHAMFLAG']==1)]
        a = (len(m)/len(y))/100

    return a

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
fig.subplots_adjust(wspace=0.3)
plt.subplot(1, 2, 2)


# Make a random dataset:
height = [cleanmeth18(df15),cleanmeth18(df16),cleanmeth18(df17),cleanmeth18(df18), cleanmeth18(df19),cleanmeth18(df20),cleanmeth18(df21)]
bars = ('2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel(' Methamphetamine in adult >18 and < 26 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)




plt.subplot(1, 2, 1)

height = [cleanmeth(df15),cleanmeth(df16),cleanmeth(df17),cleanmeth(df18), cleanmeth(df19),cleanmeth(df20),cleanmeth(df21)]
bars = ('2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel(' Methamphetamine in Kids under 18 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic

plt.suptitle(" Methamphetamine over year between 2 groups", fontweight='bold', fontsize=30)
plt.show()

# %%
def cleanLSD (x):
    y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
    m= y[(y['LSD']==1)]
    a = (len(m)/len(y))*100
    return a

# %%
def LSD2021(x):
     y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
     m= y[(y['LSD']==1)]
     a = (len(m)/len(y))*100
     return a

# %%
height = [cleanLSD(df15),cleanLSD(df16),cleanLSD(df17),cleanLSD(df18), cleanLSD(df19),cleanLSD(df20),LSD2021(df21)]
bars = ('2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))
# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('LSD in Youth by years', fontweight ='bold', fontsize = 15)
plt.ylabel('%', fontweight ='bold', fontsize = 15)
# Show graphic
plt.show()

# %%
def cleanlsd18(x):

    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 3)] and (x['AGE2']<=6)]
        m= y[(y['LSD']==1)]
        a = (len(m)/len(y))/100

    else:
        y= x[[(x['AGE3']> 3)] and (x['AGE3']<=6)]
        m= y[(y['LSD']==1)]
        a = (len(m)/len(y))/100

    return a

# %%
def cleanlsd(x):
    if 'AGE2' in x.columns:
        y= x[[(x['AGE2']> 1)] and (x['AGE2']<=3)]
        m= y[(y['LSD']==1)]
        a = (len(m)/len(y))/100

    else:
        y= x[[(x['AGE3']> 1)] and (x['AGE3']<=3)]
        m= y[(y['LSD']==1)]
        a = (len(m)/len(y))/100

    return a

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
fig.subplots_adjust(wspace=0.3)
plt.subplot(1, 2, 2)


# Make a random dataset:
height = [cleanlsd18(df10),cleanlsd18(df11),cleanlsd18(df12),cleanlsd18(df13),cleanlsd18(df14),
cleanlsd18(df15),cleanlsd18(df16),cleanlsd18(df17),cleanlsd18(df18), cleanlsd18(df19),cleanlsd18(df20),cleanlsd18(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('LSD in adult >18 and < 26 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)




plt.subplot(1, 2, 1)

height = [cleanlsd(df10),cleanlsd(df11),cleanlsd(df12),cleanlsd(df13),cleanlsd(df14),
cleanlsd(df15),cleanlsd(df16),cleanlsd(df17),cleanlsd(df18), cleanlsd(df19),cleanlsd(df20),cleanlsd(df21)]
bars = ('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('LSD in Kids under 18 ', fontweight='bold', fontsize=12)
plt.ylabel('%', fontweight='bold', fontsize=15)

# Show graphic

plt.suptitle("LSD over year between 2 groups", fontweight='bold', fontsize=30)
plt.show()
